# %% [markdown]
# ## Preprocessing for data visualisation model

# %%
import pandas as pd
import numpy as np
import matplotlib.pylab as plt
import matplotlib.pyplot as plt
# %matplotlib inline
from matplotlib import rcParams

# %%
from matplotlib.backends.backend_pdf import PdfPages

# %%
from matplotlib import rcParams

# %%
df=pd.read_csv('DS_DATESET.csv')
df
# Out:
#          ID First Name Last Name      City        State  Zip Code  \
# 0         1     Barron    Harnes  Kolhapur  Maharashtra    416004
# 1         2      Velma    Allone      Pune  Maharashtra    411011
# 2         3    Thibaut  Scotland    Mumbai  Maharashtra    400059
# 3         4      Retha     Proud   Solapur  Maharashtra    413224
# 4         5        Del    Pearse    Sangli  Maharashtra    416436
# ...     ...        ...       ...       ...          ...       ...
# 9995   9996     Paulie    Wilden    Sangli  Maharashtra    416410
# 9996   9997     Domini    Napton    Mumbai  Maharashtra    400059
# 9997   9998     Adoree  Westwick  Kolhapur  Maharashtra    416007
# 9998   9999    Germain     Imlen    Sangli  Maharashtra    416415
# 9999  10000     Roanne    Dallow   Solapur  Maharashtra    413224
#
#      DOB [DD/MM/YYYY]  Age  Gender              Email Address  ...  \
# 0          24/09/2000   19    Male       bharnes0@harvard.edu  ...
# 1          23/10/1997   22  Female            vallone1@i2i.jp  ...
# 2            6/2/1996   24    Male  tscotland2@opensource.org  ...
# 3          26/12/1999   20  Female         rproud3@flavors.me  ...
# 4          21/09/1996   23  Female      dpearse4@sakura.ne.jp  ...
# ...               ...  ...     ...                        ...  ...
# 9995         1/6/2000   19    Male       pwildenrn@sbwire.com  ...
# 9996       20/07/1998   21  Female   dnaptonro@deviantart.com  ...
# 9997       21/03/1998   22  Female    awestwickrp@example.com  ...
# 9998       29/01/2000   20  Female   gimlenrq@theatlantic.com  ...
# 9999         6/3/1999   21  Female     rdallowrr@bandcamp.com  ...
#
#       Knowing of Python  Have you worked on MySQL or Oracle database  \
# 0                 False                                          Yes
# 1                 False                                           No
# 2                 False                                           No
# 3                 False                                           No
# 4                  True                                           No
# ...                 ...                                          ...
# 9995              False                                          Yes
# 9996              False                                          Yes
# 9997              False                                          Yes
# 9998              False                                          Yes
# 9999              False                                           No
#
#      Have you studied OOP Concepts  \
# 0                               No
# 1                              Yes
# 2                               No
# 3                              Yes
# 4                              Yes
# ...                            ...
# 9995                           Yes
# 9996                           Yes
# 9997                            No
# 9998                           Yes
# 9999                            No
#
#      Certifications/Achievement/ Research papers  \
# 0                                            NaN
# 1                                            NaN
# 2                                            NaN
# 3                                            NaN
# 4                                            NaN
# ...                                          ...
# 9995                                         NaN
# 9996                                         NaN
# 9997                                         NaN
# 9998                                         NaN
# 9999                                         NaN
#
#      Rate your written communication skills [1-10]  \
# 0                                                6
# 1                                               10
# 2                                                8
# 3                                                9
# 4                                                8
# ...                                            ...
# 9995                                             9
# 9996                                             7
# 9997                                             7
# 9998                                             7
# 9999                                             6
#
#      Rate your verbal communication skills [1-10]  \
# 0                                              10
# 1                                               7
# 2                                               6
# 3                                               6
# 4                                               6
# ...                                           ...
# 9995                                            9
# 9996                                            7
# 9997                                            7
# 9998                                            6
# 9999                                           10
#
#      Link to updated Resume (Google/ One Drive link preferred)  \
# 0                                                   NaN
# 1                                                   NaN
# 2                                                   NaN
# 3                                                   NaN
# 4                                                   NaN
# ...                                                 ...
# 9995                                                NaN
# 9996                                                NaN
# 9997                                                NaN
# 9998                                                NaN
# 9999                                                NaN
#
#      link to Linkedin profile  How Did You Hear About This Internship?  \
# 0                         NaN                                  Twitter
# 1                         NaN                      Ex/Current Employee
# 2                         NaN                                  Twitter
# 3                         NaN                                  Twitter
# 4                         NaN                                 Facebook
# ...                       ...                                      ...
# 9995                      NaN                                 Facebook
# 9996                      NaN                                   Friend
# 9997                      NaN                                Newspaper
# 9998                      NaN                                Blog post
# 9999                      NaN                                 Facebook
#
#            Label
# 0     ineligible
# 1       eligible
# 2     ineligible
# 3     ineligible
# 4     ineligible
# ...          ...
# 9995    eligible
# 9996    eligible
# 9997    eligible
# 9998  ineligible
# 9999  ineligible
#
# [10000 rows x 34 columns]

# %%
missing_data = df.isnull()
missing_data
# Out:
#          ID  First Name  Last Name   City  State  Zip Code  DOB [DD/MM/YYYY]  \
# 0     False       False      False  False  False     False             False
# 1     False       False      False  False  False     False             False
# 2     False       False      False  False  False     False             False
# 3     False       False      False  False  False     False             False
# 4     False       False      False  False  False     False             False
# ...     ...         ...        ...    ...    ...       ...               ...
# 9995  False       False      False  False  False     False             False
# 9996  False       False      False  False  False     False             False
# 9997  False       False      False  False  False     False             False
# 9998  False       False      False  False  False     False             False
# 9999  False       False      False  False  False     False             False
#
#         Age  Gender  Email Address  ...  Knowing of Python  \
# 0     False   False          False  ...              False
# 1     False   False          False  ...              False
# 2     False   False          False  ...              False
# 3     False   False          False  ...              False
# 4     False   False          False  ...              False
# ...     ...     ...            ...  ...                ...
# 9995  False   False          False  ...              False
# 9996  False   False          False  ...              False
# 9997  False   False          False  ...              False
# 9998  False   False          False  ...              False
# 9999  False   False          False  ...              False
#
#       Have you worked on MySQL or Oracle database  \
# 0                                           False
# 1                                           False
# 2                                           False
# 3                                           False
# 4                                           False
# ...                                           ...
# 9995                                        False
# 9996                                        False
# 9997                                        False
# 9998                                        False
# 9999                                        False
#
#       Have you studied OOP Concepts  \
# 0                             False
# 1                             False
# 2                             False
# 3                             False
# 4                             False
# ...                             ...
# 9995                          False
# 9996                          False
# 9997                          False
# 9998                          False
# 9999                          False
#
#       Certifications/Achievement/ Research papers  \
# 0                                            True
# 1                                            True
# 2                                            True
# 3                                            True
# 4                                            True
# ...                                           ...
# 9995                                         True
# 9996                                         True
# 9997                                         True
# 9998                                         True
# 9999                                         True
#
#       Rate your written communication skills [1-10]  \
# 0                                             False
# 1                                             False
# 2                                             False
# 3                                             False
# 4                                             False
# ...                                             ...
# 9995                                          False
# 9996                                          False
# 9997                                          False
# 9998                                          False
# 9999                                          False
#
#       Rate your verbal communication skills [1-10]  \
# 0                                            False
# 1                                            False
# 2                                            False
# 3                                            False
# 4                                            False
# ...                                            ...
# 9995                                         False
# 9996                                         False
# 9997                                         False
# 9998                                         False
# 9999                                         False
#
#       Link to updated Resume (Google/ One Drive link preferred)  \
# 0                                                  True
# 1                                                  True
# 2                                                  True
# 3                                                  True
# 4                                                  True
# ...                                                 ...
# 9995                                               True
# 9996                                               True
# 9997                                               True
# 9998                                               True
# 9999                                               True
#
#       link to Linkedin profile  How Did You Hear About This Internship?  Label
# 0                         True                                    False  False
# 1                         True                                    False  False
# 2                         True                                    False  False
# 3                         True                                    False  False
# 4                         True                                    False  False
# ...                        ...                                      ...    ...
# 9995                      True                                    False  False
# 9996                      True                                    False  False
# 9997                      True                                    False  False
# 9998                      True                                    False  False
# 9999                      True                                    False  False
#
# [10000 rows x 34 columns]

# %%
a=df.drop(["Certifications/Achievement/ Research papers",
                  "Link to updated Resume (Google/ One Drive link preferred)","link to Linkedin profile"], axis = 1)

# %%
b=df.astype({'CGPA/ percentage': 'float','Rate your written communication skills [1-10]': 'int32',"Rate your verbal communication skills [1-10]":"int32"}).dtypes

# %% [markdown]
# ## Data cleaning for classification model

# %%
df = pd.read_csv("DS_DATESET.csv", delimiter=",")

# %%
df=df.drop(["ID","First Name","Last Name","State","Zip Code","DOB [DD/MM/YYYY]","Email Address","Contact Number","Emergency Contact Number"],axis=1)

# %%
df=df.drop(["University Name","Degree","Course Type","Expected Graduation-year","Current Employment Status","Knowing of Python","Certifications/Achievement/ Research papers","Link to updated Resume (Google/ One Drive link preferred)","link to Linkedin profile"],axis=1)

# %%
df1=df.drop(["Label"],axis=1)

# %%
df1.rename(columns = {"College name":"College","Major/Area of Study":"Department","Which-year are you studying in?":"Year","CGPA/ percentage":"CGPA","Areas of interest":"Interest","Have you worked core Java":"KnowingJava","Programming Language Known other than Java (one major)":"OtherLangauge","Have you worked on MySQL or Oracle database":"KnowingSQL","Have you studied OOP Concepts":"KnowingOOP","Rate your written communication skills [1-10]":"WrittenSkills","Rate your verbal communication skills [1-10]":"VerbalSkills","How Did You Hear About This Internship?":"Source"}, inplace = True)
